# %% [markdown]
# # You do not need to do any of this
# This file walks you through the preprocessing steps for:
# 1. Cleaning the data,
# 2. Aligning transcripts to utterances at the phoneme level, and
# 3. Packaging the data for data science and machine learning uses.
#
# **This is a slow, painful, and iterative process. If you're just interested in data science / machine learning, I recommend skipping this and downloading the end results.**
#
# If you want to help out with programmatic data cleaning, then this is for you. There's a lot of work to be done here.

# %% [markdown]
# # Convert clipper-formatted data to mfa-formatted data
# The goal here is to run Montreal Forced Aligner (MFA) through Clipper's clips. Clipper's files are flac files and word-level transcripts. MFA takes in 16khz wave files and word-level transcripts, and it outputs phoneme-level transcripts. The `datapipes` module in `src/` can convert Clipper's files into MFA-compatible input.
#
# First step: do a dry-run to check for any errors in the Clipper files we have. Sometimes there's a filename mismatch, a missing character name, missing transcript file, or similar. While running this, you'll see the `In [ ]` on the left-hand side change to `In [*]`. When it's complete, you'll see it change to `In [1]`. The number `[1]` tells you the order in which commands on this page were executed.

# %%
!(cd ../src; python -m datapipes --mfa-inputs \
    --input /home/celestia/data/clipper-samples `# clipper-formatted directory` \
    --output /home/celestia/data/mfa-inputs `# mfa-formatted directory` \
    --delta `# ignore files already processed` \
    --dry-run `# don't create any output files`)

# %% [markdown]
# If there are any errors, make sure to fix them and re-run the above command. Repeat until there are no errors, then run the next command to generate the mfa-formatted data. If you're running this on all of Clipper's data, this might take an hour to complete.

# %%
!(cd ../src; python -m datapipes --mfa-inputs \
    --input /home/celestia/data/clipper-samples \
    --output /home/celestia/data/mfa-inputs \
    --delta)

# %% [markdown]
# Finally, run montreal-forced-aligner with the following command to generate phoneme-level transcripts. Note that, due to quirks with IPython, this command won't produce intermediate output, so you won't be able to monitor progress here. If you're running this on all of Clipper's data, this command might take a few hours to complete. You can monitor progress by watching the `data/mfa-alignments` directory.

# %%
# %%bash
#
# function mfa() {
#     mkdir /home/celestia/data/mfa-alignments/$1 || true
#
#     yes n | mfa_align -v `# continue even with an incomplete dictionary` \
#         /home/celestia/data/mfa-inputs/$1 `# input directory` \
#         /opt/mfa/pronunciations_dicts/english.dict.txt \
#         /opt/mfa/pretrained_models/english.zip \
#         /home/celestia/data/mfa-alignments/$1 `# output directory` \
#         || true
# }
#
# export -f mfa
#
# ls /home/celestia/data/mfa-inputs | xargs -L1 -P16 bash -c 'mfa $@' _
# Out:
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 19.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 1.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 2.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 7.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 3.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 20.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 49.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 1.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 56.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 2.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 18.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 61.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 36.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 3.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 7.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 137.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 19.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 18.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 20.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 49.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 36.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 61.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 56.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 338.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 6.0252251625061035 seconds
# Done! Everything took 6.247176170349121 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 137.0
# Done with setup.
# Done! Everything took 6.58015775680542 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 45.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 8.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 8.551025152206421 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 8.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 31.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 45.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 31.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 21.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 21.0
# Done with setup.
# Done! Everything took 11.780733823776245 seconds
# Done! Everything took 12.129929304122925 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 338.0
# Done with setup.
# Done! Everything took 14.213929176330566 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 17.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 14.260009050369263 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 21.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 17.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 21.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 28.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 10.171804189682007 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 28.0
# Done with setup.
# Done! Everything took 19.54351782798767 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 334.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 104.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating MFCCs...
# Done! Everything took 12.343047618865967 seconds
# Done! Everything took 21.88569712638855 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker:
seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 40.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 20.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 98.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 40.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 13.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 38.56263017654419 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 13.0
# Done with setup.
# Done! Everything took 66.56264662742615 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 98.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 93.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 26.901570081710815 seconds
# Done! Everything took 11.592340230941772 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 5.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 5.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 93.0
# Done with setup.
# Done! Everything took 12.79106855392456 seconds
# Done! Everything took 16.252312183380127 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 42.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 11.25368332862854 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 42.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 509.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 1.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 1.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Done with setup.
# Done! Everything took 10.03340196609497 seconds
# Done! Everything took 7.837335586547852 seconds
# Done! Everything took 72.68093824386597 seconds
# Done! Everything took 9.470731973648071 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 19.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 49.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 89.05199146270752 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 19.0
# Done with setup.
# Done! Everything took 10.292258977890015 seconds
# Done! Everything took 28.04527497291565 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 31.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 49.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 429.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 2.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 2.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 31.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 38.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 38.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 289.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 21.910035848617554 seconds
# Done! Everything took 7.67799711227417 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 98.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Done with setup.
# Done! Everything took 18.000722646713257 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 289.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 98.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 30.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 30.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 429.0
# Done with setup.
# Done! Everything took 15.582113981246948 seconds
# Done! Everything took 28.914517641067505 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 6.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 26.088818073272705 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 6.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 9.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 9.0
# Done with setup.
# Done! Everything took 49.534565925598145 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Done! Everything took 32.19757032394409 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 4.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 20.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 20.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 41.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 18.363739728927612 seconds
# Done! Everything took 10.324687242507935 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 41.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 5.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Done! Everything took 9.121381282806396 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 5.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 16.0
# Done with setup.
# Done! Everything took 12.59650444984436 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 55.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 66.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 55.0
# Done with setup.
# Done! Everything took 13.894140005111694 seconds
# Done! Everything took 10.999372720718384 seconds
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 66.0
# Done with setup.
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Creating dictionary information...
# Setting up training data...
# Calculating MFCCs...
# Done! Everything took 73.5246913433075 seconds
# Setting up corpus information...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Creating dictionary information...
# Setting up training data...
# There were words not found in the dictionary. Would you like to abort to fix them? (Y/N)Calculating MFCCs...
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Done with setup.
# Calculating CMVN...
# Number of speakers in corpus: 1, average number of utterances per speaker: 10.0
# Done with setup.
# Setting up corpus information...
# ...
# 100%|██████████| 2/2 [00:09<00:00,  4.85s/it]
# 100%|██████████| 2/2 [00:07<00:00,  3.53s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  1.86s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:18<00:00,  9.68s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  1.94s/it]
# 100%|██████████| 2/2 [00:13<00:00,  7.09s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:11<00:00,  5.90s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.97s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:05<00:00,  2.67s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.63s/it]
# 100%|██████████| 2/2 [00:09<00:00,  4.90s/it]
# 100%|██████████| 2/2 [00:26<00:00, 13.33s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:25<00:00, 12.89s/it]
# 100%|██████████| 2/2 [01:33<00:00, 49.35s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:05<00:00,  2.63s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:04<00:00,  2.33s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:21<00:00, 11.13s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# 100%|██████████| 2/2 [00:08<00:00,  4.39s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#  50%|█████     | 1/2 [00:14<00:14, 14.45s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  1.72s/it]
#  50%|█████     | 1/2 [00:02<00:02,  2.33s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:28<00:00, 14.24s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.48s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:18<00:00,  9.47s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:15<00:00,  8.01s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.32s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [02:19<00:00, 69.11s/it]
#  50%|█████     | 1/2 [00:17<00:17, 17.89s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:06<00:00,  3.19s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:34<00:00, 17.64s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:07<00:00,  3.64s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:11<00:00,  5.72s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:05<00:00,  3.00s/it]
# 100%|██████████| 2/2 [00:30<00:00, 15.49s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# 100%|██████████| 2/2 [00:20<00:00, 10.43s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.78s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  1.95s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:13<00:00,  6.89s/it]
# 100%|██████████| 2/2 [00:16<00:00,  8.56s/it]
# 100%|██████████| 2/2 [00:08<00:00,  4.19s/it]
#  50%|█████     | 1/2 [00:14<00:14, 14.95s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:04<00:00,  2.10s/it]
# 100%|██████████| 2/2 [00:29<00:00, 14.80s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:07<00:00,  3.75s/it]
#  50%|█████     | 1/2 [00:02<00:02,  2.22s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:04<00:00,  2.25s/it]
#  50%|█████     | 1/2 [00:01<00:01,  1.33s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:03<00:00,  2.00s/it]
# 100%|██████████| 2/2 [00:08<00:00,  3.99s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:56<00:00, 28.64s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#  50%|█████     | 1/2 [00:03<00:03,  3.33s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
#  50%|█████     | 1/2 [00:02<00:02,  2.62s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:05<00:00,  2.59s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   0%|          | 0/2 [00:00<?, ?it/s]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:10<00:00,  5.29s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# 100%|██████████| 2/2 [00:18<00:00,  9.48s/it]
# 100%|██████████| 2/2 [00:16<00:00,  8.27s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [00:32<00:00, 16.44s/it]
#  50%|█████     | 1/2 [01:11<01:11, 71.17s/it]/opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [03:56<00:00, 126.76s/it]
# 100%|██████████| 2/2 [02:04<00:00, 65.96s/it]
# 100%|██████████| 2/2 [01:03<00:00, 32.13s/it]
# 100%|██████████| 2/2 [01:47<00:00, 56.38s/it]
# 100%|██████████| 2/2 [02:20<00:00, 69.99s/it]
# 100%|██████████| 2/2 [04:03<00:00, 124.31s/it]
# 100%|██████████| 2/2 [03:30<00:00, 108.08s/it]
# 100%|██████████| 2/2 [04:34<00:00, 139.52s/it]
# /opt/mfa/lib/aligner/models.py:87: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# 100%|██████████| 2/2 [04:41<00:00, 145.20s/it]
# 100%|██████████| 2/2 [05:03<00:00, 156.67s/it]
# 100%|██████████| 2/2 [07:09<00:00, 239.15s/it]
# 100%|██████████| 2/2 [06:12<00:00, 188.67s/it]

# %% [markdown]
# It's extremely likely that MFA failed on some inputs. There are three ways in which it can fail:
# 1. MFA found a word it didn't recognize and logged both the missing word and corresponding utterance.
# 2. MFA failed in some unexpected way while doing preprocessing for a character, and it borked its own configuration files.
# 3. MFA couldn't figure out how to align the transcript to an utterance.
#
# For the first kind of failure, you can find an `oovs_found.txt` file in each of the directories within `mfa-alignments`. This file contains a list of words that could not be processed because they don't exist in the pronunciation dictionary. You can find the current pronunciation dictionary in `/opt/mfa/pronunciations_dicts/english.dict.txt`. If you end up adding the pronunciations of any missing words, make sure to post them to the thread. I can update the Docker image so everyone can benefit from it.

# %%
! head /home/celestia/data/mfa-alignments/Twilight-Sparkle/oovs_found.txt
# Out:
# 'bout
# 'til
# 28.1
# aaaaaaah
# aaand
# accelerative
# actaully
# adoreable
# ahuizotl
# aj

# %% [markdown]
# For the second and third kinds of failure, you can find out which characters MFA failed to process by searching for the empty directories  in `mfa-alignments`.

# %%
! find /home/celestia/data/mfa-alignments -type d -empty

# %% [markdown]
# If the above command produces any output, it's very likely that MFA stochastically borked something during its own preprocessing stage. The easiest way to handle this is to remove its character-specific cache directory and try again.
#
# The following script does exactly that for the case where MFA fails on Applejack's files. In my case, I needed to run this for Apple-Bloom, Applejack, Cadance, and Rainbow-Dash the most recent time, but MFA's failures are pretty stochastic.

# %%
# %%bash
#
# retry_character="Applejack"
#
# rm -r "/home/celestia/Documents/MFA/$retry_character"
#
# yes n | mfa_align -v \
#         /home/celestia/data/mfa-inputs/$retry_character \
#         /opt/mfa/pronunciations_dicts/english.dict.txt \
#         /opt/mfa/pretrained_models/english.zip \
#         /home/celestia/data/mfa-alignments/$retry_character

# %% [markdown]
# The last type of MFA failure is the only one that's complicated to handle. If you run the following command, you can see a list of transcripts that MFA failed to align.

# %%
# %%bash
#
# function get_textgrids() {
#     (cd "$1"
#     find -iname '*.textgrid' |
#         sed 's/\.textgrid$//gI' |
#         sort)
# }
#
# diff <(get_textgrids /home/celestia/data/mfa-inputs) <(get_textgrids /home/celestia/data/mfa-alignments)
# Out:
# 32d31
# < ./AK-Yearling/AK-Yearling-s4e4-546.878969-552.430138
# 847d845
# < ./Apple-Bloom/Apple-Bloom-s3e4-155.811699-158.691000
# 883d880
# < ./Apple-Bloom/Apple-Bloom-s3e4-54.025283-57.379283
# 1186d1182
# < ./Apple-Bloom/Apple-Bloom-s4e9-117.432683-121.522084
# 1191d1186
# < ./Apple-Bloom/Apple-Bloom-s4e9-132.837474-135.650000
# 1263d1257
# < ./Apple-Bloom/Apple-Bloom-s5e17-262.677720-268.582433
# 1416,1417d1409
# < ./Apple-Bloom/Apple-Bloom-s5e4-237.844548-239.244548
# < ./Apple-Bloom/Apple-Bloom-s5e4-239.800274-242.380419
# 2278d2269
# < ./Applejack/Applejack-EQG-LoE-993.158000-997.359141
# 2399d2389
# < ./Applejack/Applejack-MLP-Movie-1111.150440-1119.251441
# 7165d7154
# < ./Big-Macintosh/Big-Macintosh-s6e23-465.757000-468.551000
# 7611d7599
# < ./Cadance/Cadance-s4e11-1021.438863-1023.570000
# 7877d7864
# < ./Capper/Capper-MLP-Movie-4182.755498-4185.892560
# 8050d8036
# < ./Celestia/Celestia-EQG-RR-2419.197799-2426.514495
# 8052d8037
# < ./Celestia/Celestia-EQG-RR-2826.078665-2830.600109
# 8851d8835
# < ./Cheerilee/Cheerilee-s1e18-1199.266000-1201.893232
# 11817d11800
# < ./Flam/Flam-s6e20-982.918695-984.394372
# 12302d12284
# < ./Fluttershy/Fluttershy-s1e1-909.432731-911.259421
# 12406,12407d12387
# < ./Fluttershy/Fluttershy-s1e16-1117.972006-1123.547926
# 45663d45464
# < ./Tempest-Shadow/Tempest-Shadow-MLP-Movie-1862.596738-1867.339237
# 45728d45528
# < ./Tempest-Shadow/Tempest-Shadow-MLP-Movie-4067.446940-4070.940766
# 45924d45723
# < ./Thorax/Thorax-s6e16-790.280431-792.474920
# 46731d46529
# < ./Trixie/Trixie-s6e6-1116.971142-1119.378052
# 46776d46573
# < ./Trixie/Trixie-s6e6-797.566118-799.600118
# 47918,47920d47714
# < ./Twilight-Sparkle/Twilight-Sparkle-MLP-Movie-621.706000-626.372866
# < ./Twilight-Sparkle/Twilight-Sparkle-MLP-Movie-626.375941-629.316168
# < ./Twilight-Sparkle/Twilight-Sparkle-MLP-Movie-629.482248-633.671148
# 47922d47715
# < ./Twilight-Sparkle/Twilight-Sparkle-MLP-Movie-637.786236-644.537070
# 48188d47980
# < ./Twilight-Sparkle/Twilight-Sparkle-s1e11-11.439223-13.448177
# 48831d48622
# < ./Twilight-Sparkle/Twilight-Sparkle-s1e22-849.950000-855.002726
# 48836d48626
# < ./Twilight-Sparkle/Twilight-Sparkle-s1e22-867.167000-871.251293
# 49127d48916
# < ./Twilight-Sparkle/Twilight-Sparkle-s1e3-683.440563-684.611075
# 49564d49352
# < ./Twilight-Sparkle/Twilight-Sparkle-s1e9-1234.290761-1237.542020
# 50213d50000
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e20-860.544025-862.839354
# 50282d50068
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e21-998.679128-1001.818724
# 50296,50297d50081
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e22-1125.185674-1128.480674
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e22-1128.636833-1130.261833
# 50300d50083
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e22-1165.820675-1168.426675
# 50591d50373
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e3-1056.426125-1058.356125
# 50686d50467
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e3-599.519040-603.048040
# 50707d50487
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e3-755.264572-756.997572
# 50710d50489
# < ./Twilight-Sparkle/Twilight-Sparkle-s2e3-772.999694-775.638694
# 50980d50758
# < ./Twilight-Sparkle/Twilight-Sparkle-s3e10-111.527285-113.979129
# 51438d51215
# < ./Twilight-Sparkle/Twilight-Sparkle-s4e1-325.530523-329.282593
# 52207d51983
# < ./Twilight-Sparkle/Twilight-Sparkle-s4e3-69.500442-71.816003
# 52462d52237
# < ./Twilight-Sparkle/Twilight-Sparkle-s5e11-13.108389-14.860389
# 53245d53019
# < ./Twilight-Sparkle/Twilight-Sparkle-s5e26-78.342541-82.448446
# 53547d53320
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e19-1017.815914-1021.662250
# 53550,53551d53322
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e19-1029.828014-1033.130465
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e19-1033.164014-1035.792014
# 53727d53497
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e24-263.510724-265.206637
# 53848d53617
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e6-437.302402-443.284280
# 53897d53665
# < ./Twilight-Sparkle/Twilight-Sparkle-s6e7-1036.504858-1039.648777
# 54500d54267
# < ./Twilight-Sparkle/Twilight-Sparkle-s7e22-79.245132-82.424848
# 55695d55461
# < ./Twilight-Sparkle/Twilight-Sparkle-s8e7-575.326545-577.178975
# 55735d55500
# < ./Twilight-Sparkle/Twilight-Sparkle-s8e7-972.008329-973.229163
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-13-d73e9266e8a0> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nfunction get_textgrids() {\n    (cd "$1"\n    find -iname \'*.textgrid\' |\n        sed \'s/\\.textgrid$//gI\' |\n        sort)\n}\n\ndiff <(get_textgrids /home/celestia/data/mfa-inputs) <(get_textgrids /home/celestia/data/mfa-alignments)\n')
#
# ~/.local/share/virtualenvs/synthbot-a79ngun7/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~/.local/share/virtualenvs/synthbot-a79ngun7/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# </home/celestia/.local/share/virtualenvs/synthbot-a79ngun7/lib/python3.6/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# ~/.local/share/virtualenvs/synthbot-a79ngun7/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/share/virtualenvs/synthbot-a79ngun7/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nfunction get_textgrids() {\n    (cd "$1"\n    find -iname \'*.textgrid\' |\n        sed \'s/\\.textgrid$//gI\' |\n        sort)\n}\n\ndiff <(get_textgrids /home/celestia/data/mfa-inputs) <(get_textgrids /home/celestia/data/mfa-alignments)\n'' returned non-zero exit status 1.

# %% [markdown]
# If you didn't complete the above steps for handling whole-character issues, you'll notice that some characters have a huge number of utterances listed. If you did complete the above steps, none of the characters should have _that_ many failures. For me, the worst offender is Pinkie Pie with 77 failures, followed by Fluttershy and Twilight Sparkle both with around 35. If a character has a huge number of utterances listed, it's likely that MFA crashed at some point. You can read through its logs in `/home/celestia/Documents/MFA/` to try to figure out why.
#
# You can try playing some of the listed files to figure out why MFA might be failing on them. I've found that it's often because either (1) the character is speaking in a very excited or abnormal way, (2) the clip is noisy or muffled, or (3) the utterance contains a lot of out-of-dictionary words.
#
# Eventually, we'll want to find a way to make use of these utterances to generate more realistic speech in niche cases, but for now we can ignore them.

# %% [markdown]
# # Packaging data for tensorflow

# %%
!(cd ../src; python -m datapipes --audio-tgz \
    --input-audio /home/celestia/data/clipper-samples `# clipper-formatted directory` \
    --input-alignments /home/celestia/data/mfa-alignments `# mfa-formatted directory` \
    --output /home/celestia/data/audio-tgz `# output per-character tar.gz files here` \
    --audio-format 'wav' \
    --sampling-rate 48000 \
    --dry-run `# don't create any output files` \
    --verbose)

# %%
!(cd ../src; python -m datapipes --audio-tgz \
    --input-audio /home/celestia/data/clipper-samples \
    --input-alignments /home/celestia/data/mfa-alignments/Twilight-Sparkle \
    --output /home/celestia/data/audio-tgz \
    --audio-format 'wav' \
    --sampling-rate 48000 \
    --verbose)
# Out:
# reading utterances from  /home/celestia/data/clipper-samples
# reading transcipts and labels from labels.text files
# writing output files to /home/celestia/data/audio-tgz
# Done

# %%
# test the archives
